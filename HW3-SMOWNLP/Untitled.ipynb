# %%
import jieba
import snownlp
import jieba.analyse
from jieba import posseg
from snownlp import normal
from snownlp import seg
from snownlp.summary import textrank
from snownlp import SnowNLP
from gensim import models
jieba.set_dictionary('dict.txt.big')
import nltk

# %%
nltk.download('sinica_treebank')
# Out:
# [nltk_data] Downloading package sinica_treebank to
# [nltk_data]     C:\Users\TEST\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\sinica_treebank.zip.
# True

# %%
jieba.set_dictionary('dict.txt')

# %%
text1='''俄羅斯和中國密謀擺脫美元，打造以黃金為基礎的經濟體系？兩國認為依賴美元危及國安，積極拉攏新興國家小弟，創立新世界。

The Daily Coin報導(見此)，俄國瘋狂囤金，今年一到十一月，每個月俄國央行都大批買進黃金，九月購入34.2噸黃金、十月購入21.8噸黃金、十一月購入27.9噸黃金，總持有量升至1,828.88噸。要是繼續以此一速度買金，2018年第一季俄國就會擠下中國，成為全球第六大黃金持有國。

如果俄國未來幾年也拼命買金，2021年年中，俄國將超越法國，成為全球第五大黃金持有國。中國應該也每月買入黃金，只是作風較為低調，未紀錄在官方紀錄上，呈報給國際貨幣基金組織(IMF)。

中俄囤積黃金，是因為相信擁有黃金的國家就能大聲，得以制定國際規則，而且一如投行JPMorgan在美國國會聽證時所說，黃金是貨幣，其他一切皆是信貸，由此可見黃金影響力之大。俄國和中國不只大買黃金，也推動黃金在兩國銀行體系內換匯，並有意協助其他金磚國家(巴西、印度、南非)增加黃金儲備。中俄並表示，希望在北京和莫斯科打造金磚國家的黃金外匯市場。

中俄動作頻頻，之後宣布考慮連結兩國的支付系統，避開美元箝制。俄羅斯總理梅德維傑夫(Dmitry Medvedev)直言，不該放任美元獨霸世界。

RT、路透社報導，梅德維傑夫訪問中國，11月1日在記者會上表示，應該使用多種儲備貨幣、多種支付方式，才能讓金融系統維持平衡，不應該由任何一種貨幣主宰。他說，不管美國經濟多強盛，仍不時遇上問題，這會撼動整體金融界，更平衡的國際金融體制能造福所有人。

梅德維傑夫指出，中國銀聯系統興起，北京致力於讓人民幣國際化，俄國正與中國商討，是否要連結兩國的支付系統。如此一來可以避免使用美國支付系統，如Visa、Mastercard可能遇上的麻煩。

＊編者按：本文僅供參考之用，並不構成要約、招攬或邀請、誘使、任何不論種類或形式之申述或訂立任何建議及推薦，讀者務請運用個人獨立思考能力，自行作出投資決定，如因相關建議招致損失，概與《精實財經媒體》、編者及作者無涉。'''

# %%
text2='''《MINING.com》12月28日報導，2017年表現最好的貴金屬鈀金在年度的最後一週仍沒有停下上漲的腳步，本週持續刷新17年來的新高價位，主要受到汽車市場需求強勁，以及鈀金市場供給短缺的影響。全球兩大汽車市場的最新數據顯示，中國大陸10月份的新車銷售年增2%，美國11月的新車銷售則是年增1.3%。金銀鉑鈀今年以來分別上漲12.6%、5.8%、55.7%、2.9%。

鉑鈀均用於觸媒轉化器的生產，分別佔其總消費量的四成與八成比重。鈀金主要用於汽油車，中、美為兩大市場；鉑金則主要用於柴油車，歐洲為最大市場。除了歐洲車市的表現不若中美兩國以外，電動車的崛起也是刺激鈀金價格的主因之一，因當前的混合動力電動車主要為汽油引擎，因此分析師表示電動車的前景看好也將利好鈀金。

加拿大皇家銀行財富管理（RBC Wealth Management）執行董事具羅（George Gero）表示，美國第四季遭遇幾個大型颶風的侵襲，這令換車的需求增加；而除了汽車市場的需求強勁之外，鈀金也不像鉑金那樣容易從報廢汽車當中回收，這令鈀金的短缺更加明顯，同時也令鈀金對鉑金的溢價創下16年來新高。

全球最大鈀金生產商俄羅斯諾里爾斯克鎳業公司（Norilsk Nickel）報告表示，受到汽車部門的需求持續增長，以及新增礦產供應受限的影響，2017年全球鈀金需求將達到創新高的1,080萬盎司，供需缺口則是將超過100萬盎司。報告指出，鈀金中期的需求增長趨勢穩健，因新興國家的收入增長持續帶動汽車的銷售，為鈀金提供穩定的需求增長動能。另一方面，鈀金的新增礦產供應則是受限，因礦商的資本投資維持在過去六年以來的新低，使得新項目的開發受阻。

不過，鈀金今年以來的強勢表現也令分析師預期2018年其價格可能會遭遇修正，反觀今年以來沒有表現的鉑金則有可能出現反彈。匯豐銀行（HSBC）就認為2018年鉑金價格將可望重新恢復至高於鈀金價格，稱雖然近期鈀金價格仍可望維持對鉑金的溢價，但鈀金價格已經過熱，反觀鉑金價格則是遭到低估，因此明年稍晚鉑金價格將會重新超過鈀金價格。

匯豐銀行表示，鉑金仍然具備一些支撐因素，只是還沒有被市場反映到價格當中，包括供應受限以及投資需求增加的潛力，特別是在價格下跌之後，礦商的投資支出也將進一步縮減，這將會令鉑金市場未來的供應增長持續受限。該行也認為，市場對於柴油車市佔下滑的擔憂以及有些過度。此外，鉑金與黃金的關聯性更高，包括金融市場不確定性所引發的避險需求，以及中國大陸、印度與北美市場的首飾需求復甦等，鉑金也都可望受惠。'''

# %%
jieba.lcut(text1)
# Out:
# Building prefix dict from C:\Users\TEST\evan\Learning\pecu\snowNLP\src\dict.txt ...
# Dumping model to file cache C:\Users\TEST\AppData\Local\Temp\jieba.u4d2c89a591ee83a8e87ba3c8bba82406.cache
# Loading model cost 2.521 seconds.
# Prefix dict has been built succesfully.
# ['俄羅斯',
#  '和',
#  '中國',
#  '密謀',
#  '擺脫',
#  '美元',
#  '，',
#  '打造',
#  '以',
#  '黃金',
#  '為',
#  '基礎',
#  '的',
#  '經濟',
#  '體系',
#  '？',
#  '兩國',
#  '認為',
#  '依賴',
#  '美元',
#  '危及',
#  '國安',
#  '，',
#  '積極',
#  '拉攏',
#  '新興國家',
#  '小弟',
#  '，',
#  '創立',
#  '新世界',
#  '。',
#  '\n',
#  '\n',
#  'The',
#  ' ',
#  'Daily',
#  ' ',
#  'Coin',
#  '報導',
#  '(',
#  '見此',
#  ')',
#  '，',
#  '俄國',
#  '瘋狂',
#  '囤金',
#  '，',
#  '今年',
#  '一到',
#  '十一月',
#  '，',
#  '每個',
#  '月',
#  '俄國',
#  '央行',
#  '都',
#  '大批',
#  '買進',
#  '黃金',
#  '，',
#  '九月',
#  '購入',
#  '34.2',
#  '噸',
#  '黃金',
#  '、',
#  '十月',
#  '購入',
#  '21.8',
#  '噸',
#  '黃金',
#  '、',
#  '十一月',
#  '購入',
#  '27.9',
#  '噸',
#  '黃金',
#  '，',
#  '總',
#  '持有',
#  '量',
# ...

# %%
jieba.lcut(text2)
# Out:
# ['《',
#  'MINING',
#  '.',
#  'com',
#  '》',
#  '12',
#  '月',
#  '28',
#  '日',
#  '報導',
#  '，',
#  '2017',
#  '年',
#  '表現',
#  '最好',
#  '的',
#  '貴金屬',
#  '鈀',
#  '金',
#  '在',
#  '年度',
#  '的',
#  '最後',
#  '一週',
#  '仍',
#  '沒有',
#  '停下',
#  '上漲',
#  '的',
#  '腳步',
#  '，',
#  '本週',
#  '持續',
#  '刷新',
#  '17',
#  '年來',
#  '的',
#  '新',
#  '高價位',
#  '，',
#  '主要',
#  '受到',
#  '汽車',
#  '市場需求',
#  '強勁',
#  '，',
#  '以及',
#  '鈀',
#  '金',
#  '市場',
#  '供給',
#  '短缺',
#  '的',
#  '影響',
#  '。',
#  '全球',
#  '兩大',
#  '汽車',
#  '市場',
#  '的',
#  '最新',
#  '數據',
#  '顯示',
#  '，',
#  '中國',
#  '大陸',
#  '10',
#  '月份',
#  '的',
#  '新車',
#  '銷售',
#  '年增',
#  '2%',
#  '，',
#  '美國',
#  '11',
#  '月',
#  '的',
#  '新車',
#  '銷售',
#  '則是',
#  '年',
#  '增',
#  '1.3%',
#  '。',
#  '金銀',
#  '鉑',
#  '鈀',
#  '今年以來',
#  '分別',
#  '上漲',
#  '12.6%',
#  '、',
#  '5.8%',
#  '、',
#  '55.7%',
#  '、',
#  '2.9%',
#  '。',
#  '\n',
#  '\n',
#  '鉑',
#  '鈀',
#  '均',
#  '用於',
#  '觸媒',
#  '轉化',
#  '器',
#  '的',
#  '生產',
#  '，',
#  '分別',
#  '佔',
# ...

# %%
print("tfidf using jieba text1\n",jieba.analyse.extract_tags(text1, topK=10))
print("tfidf using jieba text2\n",jieba.analyse.extract_tags(text2, topK=10))
# Out:
# tfidf using jieba text1
#  ['黃金', '俄國', '中國', '系統', '兩國', '購入', '維傑夫', '貨幣', '國家', '應該']
# tfidf using jieba text2
#  ['鉑金', '價格', '市場', '汽車', '供應', '增長', '表現', '需求', '受限', '持續']

# %%
print("textrank using jieba : text1\n",jieba.analyse.textrank(text1, topK=10))
print("textrank using jieba : text2\n",jieba.analyse.textrank(text2, topK=10))
# Out:
# textrank using jieba : text1
#  ['兩國', '支付', '全球', '買金', '放任', '表示', '北京', '持有', '印度', '南非']
# textrank using jieba : text2
#  ['需求', '受限', '表示', '礦商', '增加', '管理', '缺口', '崛起', '新低', '鎳業']

# %%
Text1=SnowNLP(text1)
Text2=SnowNLP(text2)
print("textrank using SnowNLP : text1\n",Text1.keywords(10))
print("textrank using SnowNLP : text2\n",Text2.keywords(10))
print("cut with snowNLP")
print(Text1.words)
print(Text2.words)
# Out:
# textrank using SnowNLP : text1
#  ['國', '金', '國家', '不', '黃', '俄', '中國', '際', '幣', '體']
# textrank using SnowNLP : text2
#  ['金', '車', '需求', '新', '鉑', '鈀', '年', '持', '價格', '來']
# cut with snowNLP
# ...

# %%
t1 = normal.zh2hans(text1)
sents1 = normal.get_sentences(t)
doc1=[]
docJiebacut1=[]
for sent in sents1:
    words = seg.seg(sent)
    wordsJiebacut=jieba.lcut(sent)
#     print(wordsJiebacut)
    words = normal.filter_stop(words)
    wordsJiebacut = normal.filter_stop(wordsJiebacut)
    docJiebacut1.append(wordsJiebacut)
    doc1.append(words)

keyword_rank = textrank.KeywordTextRank(doc1)
keyword_rank.solve()
for w in keyword_rank.top_index(10):
    print(w)
# Out:
# 黄金
# 俄国
# 中国
# 国家
# 金
# 国
# 国际
# 大
# 美元
# 货币

# %%
t2 = normal.zh2hans(text2)
sents2 = normal.get_sentences(text2)
doc2=[]
docJiebacut2=[]
for sent in sents2:
    words = seg.seg(sent)
    words = normal.filter_stop(words)
    wordsJiebacut=jieba.lcut(sent)
    wordsJiebacut = normal.filter_stop(wordsJiebacut)
    doc2.append(words)
    docJiebacut2.append(wordsJiebacut)
keyword_rank = textrank.KeywordTextRank(docJiebacut2)
keyword_rank.solve()
for w in keyword_rank.top_index(10):
    print(w)
# Out:
# 鈀
# 金
# 鉑金
# 市場
# 價格
# 需求
# 年
# 汽車
# 表現

# %%
print("summary with SnowNLP:Text1\n", Text1.summary(limit=10),"\nsentiments with SnowNLP:Text1\n",Text1.sentiments)
print("summary with SnowNLP:Text2\n",Text2.summary(limit=10),"\nsentiments with SnowNLP:Text2\n",Text2.sentiments)
# Out:
# summary with SnowNLP:Text1
#  ['俄國和中國不只大買黃金', '每個月俄國央行都大批買進黃金', '中國應該也每月買入黃金', '俄國瘋狂囤金', '梅德維傑夫訪問中國', '九月購入34.2噸黃金、十月購入21.8噸黃金、十一月購入27.9噸黃金', '2018年第一季俄國就會擠下中國', '成為全球第五大黃金持有國', '如果俄國未來幾年也拼命買金', '是否要連結兩國的支付系統']
# sentiments with SnowNLP:Text1
#  0.25958252634304146
# summary with SnowNLP:Text2
#  ['2017年全球鈀金需求將達到創新高的1,080萬盎司', '匯豐銀行（HSBC）就認為2018年鉑金價格將可望重新恢復至高於鈀金價格', '鈀金主要用於汽油車', '為鈀金提供穩定的需求增長動能', '全球兩大汽車市場的最新數據顯示', '鈀金的新增礦產供應則是受限', '稱雖然近期鈀金價格仍可望維持對鉑金的溢價', '中、美為兩大市場', '歐洲為最大市場', '這將會令鉑金市場未來的供應增長持續受限']
# sentiments with SnowNLP:Text2
#  0.00614123975367431

# %%
seg1=posseg.cut(text1)
for word in seg1:
    print (word)
# Out:
# 俄羅斯/x
# 和/c
# 中國/x
# 密謀/x
# 擺脫/x
# 美元/q
# ，/x
# 打造/v
# 以/p
# 黃金/x
# 為/zg
# 基礎/x
# 的/uj
# 經濟/x
# 體系/x
# ？/x
# 兩國/ns
# 認為/v
# 依賴/x
# 美元/q
# 危及/v
# 國安/x
# ，/x
# 積極/x
# 拉攏/x
# 新興國家/x
# 小弟/n
# ，/x
# 創立/x
# 新世界/nz
# 。/x
#
# /x
#
# /x
# The/eng
#  /x
# Daily/eng
#  /x
# Coin/eng
# 報導/x
# (/x
# 見/v
# 此/r
# )/x
# ，/x
# 俄國/x
# 瘋狂/x
# 囤/v
# 金/n
# ，/x
# 今年/t
# 一/m
# 到/v
# 十一月/m
# ，/x
# 每個/x
# 月/m
# 俄國/x
# 央行/j
# 都/d
# 大批/m
# 買進/x
# 黃金/x
# ，/x
# 九月/t
# 購入/x
# 34.2/m
# 噸/m
# 黃金/x
# 、/x
# 十月/t
# 購入/x
# 21.8/m
# 噸/m
# 黃金/x
# 、/x
# 十一月/m
# 購入/x
# 27.9/m
# 噸/m
# 黃金/x
# ，/x
# 總/zg
# 持有/v
# 量/n
# 升至/v
# 1/x
# ,/x
# 828.88/m
# 噸/m
# 。/x
# 要是/c
# 繼續/x
# 以此/c
# 一/m
# 速度/n
# 買金/n
# ，/x
# 2018/m
# 年/m
# 第一季/m
# 俄國/x
# 就/d
# 會/v
# 擠下/x
# 中國/x
# ，/x
# 成為/v
# 全球/n
# 第六/m
# 大/a
# 黃金/x
# 持有/v
# 國/zg
# 。/x
#
# /x
#
# /x
# 如果/c
# 俄國/x
# 未來/x
# 幾年/x
# 也/d
# 拼命/v
# 買金/n
# ，/x
# 2021/m
# 年/m
# 年/m
# 中/f
# ，/x
# 俄國/x
# 將/zg
# 超越/v
# 法國/x
# ，/x
# 成為/v
# 全球/n
# 第五/m
# 大/a
# 黃金/x
# 持有/v
# 國/zg
# 。/x
# 中國/x
# 應該/x
# 也/d
# ...

# %%
seg2=posseg.cut(text2)
for word in seg2:
    print (word)
# Out:
# 《/x
# MINING/eng
# ./m
# com/eng
# 》/x
# 12/m
# 月/m
# 28/m
# 日/m
# 報導/x
# ，/x
# 2017/m
# 年/m
# 表現/x
# 最好/a
# 的/uj
# 貴金屬/x
# 鈀/g
# 金/ng
# 在/p
# 年度/n
# 的/uj
# 最後/x
# 一週/x
# 仍/zg
# 沒有/x
# 停下/v
# 上漲/x
# 的/uj
# 腳步/x
# ，/x
# 本週/x
# 持續/x
# 刷新/v
# 17/m
# 年來/x
# 的/uj
# 新/n
# 高價位/x
# ，/x
# 主要/b
# 受到/v
# 汽車/x
# 市場需求/x
# 強勁/x
# ，/x
# 以及/c
# 鈀/g
# 金/ng
# 市場/x
# 供給/x
# 短缺/a
# 的/uj
# 影響/x
# 。/x
# 全球/n
# 兩/m
# 大/a
# 汽車/x
# 市場/x
# 的/uj
# 最新/d
# 數據/x
# 顯示/x
# ，/x
# 中國/x
# 大陸/x
# 10/m
# 月份/n
# 的/uj
# 新車/x
# 銷售/x
# 年/m
# 增/v
# 2/m
# %/x
# ，/x
# 美國/x
# 11/m
# 月/m
# 的/uj
# 新車/x
# 銷售/x
# 則/d
# 是/v
# 年/m
# 增/v
# 1.3/m
# %/x
# 。/x
# 金銀/x
# 鉑/n
# 鈀/g
# 今年以來/x
# 分別/x
# 上漲/x
# 12.6/m
# %/x
# 、/x
# 5.8/m
# %/x
# 、/x
# 55.7/m
# %/x
# 、/x
# 2.9/m
# %/x
# 。/x
#
# /x
#
# /x
# 鉑/n
# 鈀/g
# 均/d
# 用於/x
# 觸媒/x
# 轉化/x
# 器/n
# 的/uj
# 生產/x
# ，/x
# 分別/x
# 佔/v
# 其/r
# 總/b
# 消費量/x
# 的/uj
# 四成/m
# 與/zg
# 八成/m
# 比重/n
# 。/x
# 鈀/g
# 金/ng
# 主要/b
# 用於/x
# 汽油車/x
# ，/x
# 中/f
# 、/x
# 美/j
# 為/p
# 兩/m
# 大/a
# 市場/x
# ；/x
# 鉑金/x
# 則/zg
# ...

# %%
model1 = models.word2vec.Word2Vec(docJiebacut1, size=250)
print(model1.wv.similar_by_word('黄金'))
model = models.word2vec.Word2Vec(docJiebacut2, size=250)
model.wv.similar_by_word('鈀')
# Out:
# [('俄国', -0.01179570984095335), ('系统', -0.06716178357601166), ('中国', -0.09815157204866409)]
# [('需求', 0.1279558390378952),
#  ('市場', 0.04900296777486801),
#  ('年', 0.02981480024755001),
#  ('金', 0.024094054475426674),
#  ('汽車', -0.007024167105555534),
#  ('價格', -0.028827769681811333),
#  ('鉑金', -0.040469396859407425)]

# %% [markdown]
# Manning, Christopher D., Mihai Surdeanu, John Bauer, Jenny Finkel, Steven J. Bethard, and David McClosky. 2014. The Stanford CoreNLP Natural Language Processing Toolkit In Proceedings of the 52nd Annual Meeting of the Association for Computational Linguistics: System Demonstrations, pp. 55-60. [pdf] [bib]

# %% [markdown]
# # using sinica_treebank

# %%
from nltk.corpus import sinica_treebank
sinica_treebank.parsed_sents()[15].draw()
